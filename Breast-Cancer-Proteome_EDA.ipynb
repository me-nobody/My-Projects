# %% [markdown]
# # Exploratory Data Analysis of Kaggle Breast Cancer Proteomes

# %% [markdown]
# ## Data Preparation and Cleaning
#
# #### This is a Cancer Proteome Dataset from Kaggle
#
# #### Load Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
import seaborn as sns

sns.set_style('darkgrid')
plt.rcParams['font.size'] = 22
plt.rcParams['font.family'] = 'Tahoma'
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['figure.figsize'] = (9, 5)
plt.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# #### EDA

# %%
proteome=pd.read_csv('../input/breastcancerproteomes/77_cancer_proteomes_CPTAC_itraq.csv',header=0)

# %%
proteome.head(n=3)
# Out:
#   RefSeq_accession_number gene_symbol           gene_name  AO-A12D.01TCGA  \
# 0               NP_958782        PLEC   plectin isoform 1        1.096131
# 1               NP_958785         NaN  plectin isoform 1g        1.111370
# 2               NP_958786        PLEC  plectin isoform 1a        1.111370
#
#    C8-A131.01TCGA  AO-A12B.01TCGA  BH-A18Q.02TCGA  C8-A130.02TCGA  \
# 0        2.609943       -0.659828        0.195341       -0.494060
# 1        2.650422       -0.648742        0.215413       -0.503899
# 2        2.650422       -0.654285        0.215413       -0.500619
#
#    C8-A138.03TCGA  E2-A154.03TCGA  C8-A12L.04TCGA  A2-A0EX.04TCGA  \
# 0        2.765081        0.862659        1.407570        1.185108
# 1        2.779709        0.870186        1.407570        1.192612
# 2        2.779709        0.870186        1.410312        1.188860
#
#    AO-A12D.05TCGA  AN-A04A.05TCGA  BH-A0AV.05TCGA  C8-A12T.06TCGA  \
# 0        1.100688        0.384588        0.350536       -0.204918
# 1        1.100688        0.371393        0.367405       -0.162418
# 2        1.100688        0.371393        0.367405       -0.166668
#
#    A8-A06Z.07TCGA  A2-A0CM.07TCGA  BH-A18U.08TCGA  A2-A0EQ.08TCGA  \
# 0       -0.496409        0.683404       -0.265030       -0.912670
# 1       -0.498509        0.694424       -0.251642       -0.927979
# 2       -0.496409        0.698098       -0.251642       -0.927979
#
#    AR-A0U4.09TCGA  AO-A0J9.10TCGA  AR-A1AP.11TCGA  AN-A0FK.11TCGA  \
# 0       -0.033221        0.020007        0.461088        0.973564
# 1       -0.030216        0.011955        0.461088        0.977476
# 2       -0.027212        0.011955        0.461088        0.977476
#
#    AO-A0J6.11TCGA  A7-A13F.12TCGA  BH-A0E1.12TCGA  A7-A0CE.13TCGA  \
# 0        0.831132        1.279185        0.762044       -1.123173
# 1        0.856540        1.275167        0.762044       -1.123173
# 2        0.856540        1.275167        0.766384       -1.116861
#
#    A2-A0YC.13TCGA  AO-A0JC.14TCGA  A8-A08Z.14TCGA  AR-A0TX.14TCGA  \
# 0        0.818824       -0.307267        0.568895       -0.583429
# 1        0.814877       -0.307267        0.568895       -0.572549
# 2        0.814877       -0.307267        0.568895       -0.567109
#
#    A8-A076.15TCGA  AO-A126.15TCGA  BH-A0C1.16TCGA  A2-A0EY.16TCGA  \
# 0        1.873982        0.195877       -0.518366        1.174881
# 1        1.870383        0.195877       -0.510002        1.183209
# 2        1.870383        0.195877       -0.507214        1.183209
#
#    AR-A1AW.17TCGA  AR-A1AV.17TCGA  C8-A135.17TCGA  A2-A0EV.18TCGA  \
# 0        0.578309       -0.759823        1.120502        0.452986
# 1        0.582213       -0.759823        1.137618        0.472590
# 2        0.578309       -0.749114        1.137618        0.472590
#
#    AN-A0AM.18TCGA  D8-A142.18TCGA  AN-A0FL.19TCGA  BH-A0DG.19TCGA  \
# 0        1.501967        0.538596        2.455138       -0.205637
# 1        1.510348        0.542211        2.480137       -0.205637
# 2        1.501967        0.542211        2.480137       -0.205637
#
#    AR-A0TV.20TCGA  C8-A12Z.20TCGA  AO-A0JJ.20TCGA  AO-A0JE.21TCGA  \
# 0       -1.514278       -0.787195        0.757188        0.559777
# 1       -1.528285       -0.755941        0.780871        0.563407
# 2       -1.528285       -0.755941        0.774104        0.559777
#
#    AN-A0AJ.21TCGA  A7-A0CJ.22TCGA  AO-A12F.22TCGA  A8-A079.23TCGA  \
# 0       -0.428181        -1.00124       -1.947792        1.048959
# 1       -0.406378        -1.00462       -1.952718        1.052257
# 2       -0.406378        -1.00462       -1.955180        1.052257
#
#    A2-A0T3.24TCGA  A2-A0YD.24TCGA  AR-A0TR.25TCGA  AO-A03O.25TCGA  \
# 0        0.583713        0.063779       -1.101675        1.053225
# 1        0.580623        0.093336       -1.108783        1.055948
# 2        0.580623        0.084469       -1.108783        1.055948
#
#    AO-A12E.26TCGA  A8-A06N.26TCGA  A2-A0YG.27TCGA  BH-A18N.27TCGA  \
# 0        0.264859        0.238547       -0.078202        1.101261
# 1        0.275711        0.249818       -0.068058        1.101261
# 2        0.275711        0.244183       -0.071439        1.097767
#
#    AN-A0AL.28TCGA  A2-A0T6.29TCGA  E2-A158.29TCGA  E2-A15A.29TCGA  \
# 0        0.323663        0.793976       -1.086529        2.180123
# 1        0.326973        0.818182       -1.095492        2.180123
# 2        0.326973        0.814724       -1.095492        2.180123
#
#    AO-A0JM.30TCGA  C8-A12V.30TCGA  A2-A0D2.31TCGA  C8-A12U.31TCGA  \
# 0        1.395247        0.673905        0.107491        -0.48155
# 1        1.408922        0.688718        0.104164        -0.47789
# 2        1.412341        0.688718        0.107491        -0.48155
#
#    AR-A1AS.31TCGA  A8-A09G.32TCGA  C8-A131.32TCGA  C8-A134.32TCGA  \
# 0        1.222507       -1.523343        2.707250        0.140182
# 1        1.218974       -1.512646        2.733832        0.126054
# 2        1.222507       -1.509972        2.737629        0.133118
#
#    A2-A0YF.33TCGA  BH-A0DD.33TCGA  BH-A0E9.33TCGA  AR-A0TT.34TCGA  \
# 0        0.311319       -0.692316        1.466665       -0.511421
# 1        0.296177       -0.659469        1.482283       -0.526067
# 2        0.296177       -0.664161        1.474474       -0.526067
#
#    AO-A12B.34TCGA  A2-A0SW.35TCGA  AO-A0JL.35TCGA  BH-A0BV.35TCGA  \
# 0       -0.963904       -0.487772        -0.10668       -0.065838
# 1       -0.938210       -0.487772        -0.10668       -0.055893
# 2       -0.943919       -0.487772        -0.10668       -0.065838
#
#    A2-A0YM.36TCGA  BH-A0C7.36TCGA  A2-A0SX.36TCGA  263d3f-I.CPTAC  \
# 0        0.655850       -0.552212       -0.398560        0.598585
# 1        0.658143       -0.547749       -0.392601        0.606697
# 2        0.655850       -0.552212       -0.392601        0.603993
#
#    blcdb9-I.CPTAC  c4155b-C.CPTAC
# 0       -0.191285        0.566975
# 1       -0.183918        0.578702
# 2       -0.186022        0.576747

# %%
proteome.shape
# Out:
# (12553, 86)

# %%
# extract gene description coloumns for downstream analysis
gene_name_df=proteome.loc[:,['RefSeq_accession_number','gene_symbol','gene_name']]
gene_name_df.set_index('RefSeq_accession_number',inplace=True)
gene_name_df.head()
# Out:
#                         gene_symbol           gene_name
# RefSeq_accession_number
# NP_958782                      PLEC   plectin isoform 1
# NP_958785                       NaN  plectin isoform 1g
# NP_958786                      PLEC  plectin isoform 1a
# NP_000436                       NaN  plectin isoform 1c
# NP_958781                       NaN  plectin isoform 1e

# %%
# type of features in the data
data_type=proteome.dtypes.reset_index()
data_type.columns=["count","column_type"]
data_type.groupby("column_type").aggregate("count").reset_index()
# Out:
#   column_type  count
# 0     float64     83
# 1      object      3

# %% [markdown]
# ### OBSERVATION
# #### The dataset has 12553 rows. These rows are 12553 proteins identified by iTRAQ (annotated here their NCBI Refseq database accession number and gene name)  and 86 columns. These columns are Refseq ID, gene symbol, gene name and are 83 samples with their identifiers.
# #### Thus format is rows as features and columns as samples
# #### To make it biologically meaningful, we have to reshape the data to the conventional rows as samples and columns as features

# %%
# save the accession numbers to a list
proteins=proteome.RefSeq_accession_number.tolist()

# %%
# dataset with numerical features only
proteome_samples=proteome.iloc[:,3:] 
proteome_samples.head()
# Out:
#    AO-A12D.01TCGA  C8-A131.01TCGA  AO-A12B.01TCGA  BH-A18Q.02TCGA  \
# 0        1.096131        2.609943       -0.659828        0.195341
# 1        1.111370        2.650422       -0.648742        0.215413
# 2        1.111370        2.650422       -0.654285        0.215413
# 3        1.107561        2.646374       -0.632113        0.205377
# 4        1.115180        2.646374       -0.640428        0.215413
#
#    C8-A130.02TCGA  C8-A138.03TCGA  E2-A154.03TCGA  C8-A12L.04TCGA  \
# 0       -0.494060        2.765081        0.862659        1.407570
# 1       -0.503899        2.779709        0.870186        1.407570
# 2       -0.500619        2.779709        0.870186        1.410312
# 3       -0.510459        2.797995        0.866423        1.407570
# 4       -0.503899        2.787023        0.870186        1.413053
#
#    A2-A0EX.04TCGA  AO-A12D.05TCGA  AN-A04A.05TCGA  BH-A0AV.05TCGA  \
# 0        1.185108        1.100688        0.384588        0.350536
# 1        1.192612        1.100688        0.371393        0.367405
# 2        1.188860        1.100688        0.371393        0.367405
# 3        1.185108        1.100688        0.377990        0.360657
# 4        1.200116        1.093358        0.374692        0.370779
#
#    C8-A12T.06TCGA  A8-A06Z.07TCGA  A2-A0CM.07TCGA  BH-A18U.08TCGA  \
# 0       -0.204918       -0.496409        0.683404       -0.265030
# 1       -0.162418       -0.498509        0.694424       -0.251642
# 2       -0.166668       -0.496409        0.698098       -0.251642
# 3       -0.183668       -0.492209        0.687077       -0.251642
# 4       -0.166668       -0.488010        0.687077       -0.251642
#
#    A2-A0EQ.08TCGA  AR-A0U4.09TCGA  AO-A0J9.10TCGA  AR-A1AP.11TCGA  \
# 0       -0.912670       -0.033221        0.020007        0.461088
# 1       -0.927979       -0.030216        0.011955        0.461088
# 2       -0.927979       -0.027212        0.011955        0.461088
# 3       -0.931806       -0.030216        0.003904        0.461088
# 4       -0.927979       -0.030216        0.011955        0.461088
#
#    AN-A0FK.11TCGA  AO-A0J6.11TCGA  A7-A13F.12TCGA  BH-A0E1.12TCGA  \
# 0        0.973564        0.831132        1.279185        0.762044
# 1        0.977476        0.856540        1.275167        0.762044
# 2        0.977476        0.856540        1.275167        0.766384
# 3        0.969652        0.836778        1.279185        0.757704
# 4        0.985300        0.865009        1.279185        0.766384
#
#    A7-A0CE.13TCGA  A2-A0YC.13TCGA  AO-A0JC.14TCGA  A8-A08Z.14TCGA  \
# 0       -1.123173        0.818824       -0.307267        0.568895
# 1       -1.123173        0.814877       -0.307267        0.568895
# 2       -1.116861        0.814877       -0.307267        0.568895
# 3       -1.129486        0.799090       -0.307267        0.568895
# 4       -1.129486        0.818824       -0.301033        0.568895
#
#    AR-A0TX.14TCGA  A8-A076.15TCGA  AO-A126.15TCGA  BH-A0C1.16TCGA  \
# 0       -0.583429        1.873982        0.195877       -0.518366
# 1       -0.572549        1.870383        0.195877       -0.510002
# 2       -0.567109        1.870383        0.195877       -0.507214
# 3       -0.583429        1.859587        0.218935       -0.518366
# 4       -0.572549        1.870383        0.199720       -0.512790
#
#    A2-A0EY.16TCGA  AR-A1AW.17TCGA  AR-A1AV.17TCGA  C8-A135.17TCGA  \
# 0        1.174881        0.578309       -0.759823        1.120502
# 1        1.183209        0.582213       -0.759823        1.137618
# 2        1.183209        0.578309       -0.749114        1.137618
# 3        1.174881        0.590021       -0.735727        1.137618
# 4        1.179045        0.586117       -0.749114        1.120502
#
#    A2-A0EV.18TCGA  AN-A0AM.18TCGA  D8-A142.18TCGA  AN-A0FL.19TCGA  \
# 0        0.452986        1.501967        0.538596        2.455138
# 1        0.472590        1.510348        0.542211        2.480137
# 2        0.472590        1.501967        0.542211        2.480137
# 3        0.458587        1.501967        0.534981        2.461956
# 4        0.472590        1.501967        0.542211        2.477864
#
#    BH-A0DG.19TCGA  AR-A0TV.20TCGA  C8-A12Z.20TCGA  AO-A0JJ.20TCGA  \
# 0       -0.205637       -1.514278       -0.787195        0.757188
# 1       -0.205637       -1.528285       -0.755941        0.780871
# 2       -0.205637       -1.528285       -0.755941        0.774104
# 3       -0.215006       -1.531087       -0.774693        0.763955
# 4       -0.205637       -1.514278       -0.771568        0.770721
#
#    AO-A0JE.21TCGA  AN-A0AJ.21TCGA  A7-A0CJ.22TCGA  AO-A12F.22TCGA  \
# 0        0.559777       -0.428181        -1.00124       -1.947792
# 1        0.563407       -0.406378        -1.00462       -1.952718
# 2        0.559777       -0.406378        -1.00462       -1.955180
# 3        0.541627       -0.406378        -0.99786       -1.947792
# 4        0.559777       -0.406378        -1.00124       -1.957643
#
#    A8-A079.23TCGA  A2-A0T3.24TCGA  A2-A0YD.24TCGA  AR-A0TR.25TCGA  \
# 0        1.048959        0.583713        0.063779       -1.101675
# 1        1.052257        0.580623        0.093336       -1.108783
# 2        1.052257        0.580623        0.084469       -1.108783
# 3        1.058852        0.586803        0.066734       -1.096937
# 4        1.052257        0.586803        0.084469       -1.111152
#
#    AO-A03O.25TCGA  AO-A12E.26TCGA  A8-A06N.26TCGA  A2-A0YG.27TCGA  \
# 0        1.053225        0.264859        0.238547       -0.078202
# 1        1.055948        0.275711        0.249818       -0.068058
# 2        1.055948        0.275711        0.244183       -0.071439
# 3        1.058671        0.278424        0.249818       -0.057914
# 4        1.058671        0.278424        0.249818       -0.064677
#
#    BH-A18N.27TCGA  AN-A0AL.28TCGA  A2-A0T6.29TCGA  E2-A158.29TCGA  \
# 0        1.101261        0.323663        0.793976       -1.086529
# 1        1.101261        0.326973        0.818182       -1.095492
# 2        1.097767        0.326973        0.814724       -1.095492
# 3        1.090779        0.330283        0.800892       -1.095492
# 4        1.108248        0.326973        0.818182       -1.095492
#
#    E2-A15A.29TCGA  AO-A0JM.30TCGA  C8-A12V.30TCGA  A2-A0D2.31TCGA  \
# 0        2.180123        1.395247        0.673905        0.107491
# 1        2.180123        1.408922        0.688718        0.104164
# 2        2.180123        1.412341        0.688718        0.107491
# 3        2.180123        1.408922        0.677608        0.097512
# 4        2.180123        1.408922        0.688718        0.104164
#
#    C8-A12U.31TCGA  AR-A1AS.31TCGA  A8-A09G.32TCGA  C8-A131.32TCGA  \
# 0       -0.481550        1.222507       -1.523343        2.707250
# 1       -0.477890        1.218974       -1.512646        2.733832
# 2       -0.481550        1.222507       -1.509972        2.737629
# 3       -0.470569        1.204839       -1.517995        2.733832
# 4       -0.481550        1.222507       -1.509972        2.752819
#
#    C8-A134.32TCGA  A2-A0YF.33TCGA  BH-A0DD.33TCGA  BH-A0E9.33TCGA  \
# 0        0.140182        0.311319       -0.692316        1.466665
# 1        0.126054        0.296177       -0.659469        1.482283
# 2        0.133118        0.296177       -0.664161        1.474474
# 3        0.111926        0.296177       -0.657122        1.458856
# 4        0.126054        0.296177       -0.661815        1.474474
#
#    AR-A0TT.34TCGA  AO-A12B.34TCGA  A2-A0SW.35TCGA  AO-A0JL.35TCGA  \
# 0       -0.511421       -0.963904       -0.487772        -0.10668
# 1       -0.526067       -0.938210       -0.487772        -0.10668
# 2       -0.526067       -0.943919       -0.487772        -0.10668
# 3       -0.533389       -0.935355       -0.487772        -0.10668
# 4       -0.529728       -0.935355       -0.503853        -0.10668
#
#    BH-A0BV.35TCGA  A2-A0YM.36TCGA  BH-A0C7.36TCGA  A2-A0SX.36TCGA  \
# 0       -0.065838        0.655850       -0.552212       -0.398560
# 1       -0.055893        0.658143       -0.547749       -0.392601
# 2       -0.065838        0.655850       -0.552212       -0.392601
# 3       -0.055893        0.655850       -0.552212       -0.392601
#
# ...
# C8-A131.01TCGA   2.650422  -1.680811        NaN        NaN           NaN
# AO-A12B.01TCGA  -0.978548  -5.418449        NaN        NaN           NaN
# BH-A18Q.02TCGA  -2.166499  -6.043797  -5.260977   1.128702      3.828425
# C8-A130.02TCGA   0.073358  -1.022118  -0.097195   0.906444      2.562778
#
#                 NP_443073  NP_001193949  NP_660352  NP_001138779  NP_037464  \
# AO-A12D.01TCGA  -0.119194     -1.704070   4.696390      4.696390        NaN
# C8-A131.01TCGA   1.144610     -2.846601   5.564896      5.564896        NaN
# AO-A12B.01TCGA  -1.203037     -0.895403   0.972570      0.972570        NaN
# BH-A18Q.02TCGA   1.700762     -3.671921 -14.173074           NaN  -7.743251
# C8-A130.02TCGA   0.371826     -1.150033  -0.395664           NaN   2.064238
#
#                 NP_443165  NP_001121687  NP_115950  NP_001026907  NP_620169  \
# AO-A12D.01TCGA   0.166540      1.492350   2.174304     -1.471673        NaN
# C8-A131.01TCGA  -2.749451     -0.697176  -0.810516     -0.405728        NaN
# AO-A12B.01TCGA  -1.671416     -2.489001  -0.260736      0.753624        NaN
# BH-A18Q.02TCGA        NaN     -6.910250  -5.147234     -0.313157  -5.097053
# C8-A130.02TCGA        NaN     -0.077516   0.171754      1.598497  -1.412423
#
#                 NP_945193  NP_055281  NP_115743  NP_777569  NP_653326  \
# AO-A12D.01TCGA  -0.046808   6.890834        NaN        NaN   1.347578
# C8-A131.01TCGA   1.124371   1.634404        NaN        NaN  -1.186969
# AO-A12B.01TCGA  -1.277867  -2.677461        NaN        NaN   1.083429
# BH-A18Q.02TCGA        NaN  -8.509343        NaN   0.740638  -3.906098
# C8-A130.02TCGA        NaN   1.398425        NaN  -4.544698  -0.986040
#
#                 NP_710141  NP_065954  NP_775806  NP_001264236  NP_001243586  \
# AO-A12D.01TCGA        NaN        NaN        NaN           NaN      1.892379
# C8-A131.01TCGA        NaN        NaN        NaN           NaN      1.359148
# AO-A12B.01TCGA        NaN        NaN        NaN           NaN      0.141128
# BH-A18Q.02TCGA  -3.879334        NaN        NaN     11.790434     -6.599130
# C8-A130.02TCGA   0.729332        NaN        NaN     -0.116875      0.890045
#
#                 XP_001129515  NP_004786  NP_000991  NP_001093391  NP_002243  \
# AO-A12D.01TCGA      0.882782        NaN   1.096131           NaN   0.337981
# C8-A131.01TCGA      0.278364        NaN  -0.725511           NaN   3.540956
# AO-A12B.01TCGA     -0.227478        NaN  -2.635889           NaN  -2.317169
# BH-A18Q.02TCGA      1.232409  -9.901022   0.857726     11.790434  -2.116318
# C8-A130.02TCGA      1.083557 -11.744010   2.028160     -0.116875   2.956362
#
#                 NP_542787  NP_001164102  NP_689846  NP_057700  NP_001288  \
# AO-A12D.01TCGA  -0.633517      1.198996        NaN   0.212258   2.581952
# C8-A131.01TCGA   4.840325     -0.138568        NaN  -2.757547   2.448028
# AO-A12B.01TCGA  -1.965192      0.720366        NaN   2.477480  -0.396538
# BH-A18Q.02TCGA        NaN      0.215413        NaN  -5.361339  -1.728254
# C8-A130.02TCGA        NaN      0.312788        NaN  -0.215271  -0.120155
#
#                 NP_000551  NP_742099  NP_002659  NP_071765  NP_078945  \
# AO-A12D.01TCGA        NaN        NaN   1.385676        NaN        NaN
# C8-A131.01TCGA        NaN        NaN   3.265700        NaN        NaN
# AO-A12B.01TCGA        NaN        NaN  -1.433069        NaN        NaN
# BH-A18Q.02TCGA  -1.447242 -11.647311  -2.076174        NaN   0.312429
# C8-A130.02TCGA  -0.316947   1.486981  -2.422622        NaN   1.585377
#
#                 NP_940893  NP_055716  NP_115995  XP_003960169  NP_006813  \
# AO-A12D.01TCGA   1.126610   0.909451        NaN           NaN        NaN
# C8-A131.01TCGA   1.529159   1.602021        NaN           NaN        NaN
# AO-A12B.01TCGA   1.125001  -2.877007        NaN           NaN        NaN
# BH-A18Q.02TCGA  -3.410981  -7.565945  -6.856724      -6.07725   1.466586
# C8-A130.02TCGA  -0.028318   1.503381   2.182313      -0.22511   3.372906
#
#                 NP_777552  NP_542778  NP_115996  NP_849150  XP_003960895  \
# AO-A12D.01TCGA        NaN        NaN  -0.896393        NaN           NaN
# C8-A131.01TCGA        NaN        NaN   0.335034        NaN           NaN
# AO-A12B.01TCGA        NaN        NaN  -5.612452        NaN           NaN
# BH-A18Q.02TCGA  -2.738559  -5.635660  -4.628700  -9.553102           NaN
# C8-A130.02TCGA  -2.776848   1.572258  -0.320227   1.962562           NaN
#
#                 NP_001124183  NP_699167  NP_001004456  NP_002034  NP_057156  \
# AO-A12D.01TCGA           NaN   4.734488     -2.024094        NaN   1.023745
# C8-A131.01TCGA           NaN   1.002934     -0.166903        NaN   2.808289
# AO-A12B.01TCGA           NaN  -0.584998     -3.071010        NaN   0.035812
# BH-A18Q.02TCGA           NaN  -9.466122      2.353112  -4.039913        NaN
# C8-A130.02TCGA           NaN  -0.159513     -1.445222  -3.409863        NaN
#
#                 NP_001005234  NP_001017980  NP_001087199  NP_068575  \
# AO-A12D.01TCGA           NaN      1.953336           NaN        NaN
# C8-A131.01TCGA           NaN     -0.085946           NaN        NaN
# AO-A12B.01TCGA           NaN     -0.141562           NaN        NaN
# BH-A18Q.02TCGA      1.667309           NaN    -12.781396   1.503385
# C8-A130.02TCGA      2.628376           NaN      0.106156   0.594857
#
#                 NP_653322  NP_808211  NP_001093260  NP_005622  NP_001138640  \
# AO-A12D.01TCGA        NaN        NaN           NaN        NaN           NaN
# C8-A131.01TCGA        NaN        NaN           NaN        NaN           NaN
# AO-A12B.01TCGA        NaN        NaN           NaN        NaN           NaN
# BH-A18Q.02TCGA  -1.651310        NaN           NaN   0.165232           NaN
# C8-A130.02TCGA  -0.215271        NaN           NaN   3.445063           NaN
#
#                 NP_006845  XP_003960233  NP_003262  NP_001004339  NP_443116  \
# AO-A12D.01TCGA        NaN     -2.881298   0.353221           NaN        NaN
# C8-A131.01TCGA        NaN      1.079844   0.974599           NaN        NaN
# AO-A12B.01TCGA        NaN     -1.308353  -0.033475           NaN        NaN
# BH-A18Q.02TCGA  -3.564869           NaN   0.911252     -0.748057        NaN
# C8-A130.02TCGA  -3.531218           NaN  -0.766289     -0.402223        NaN
#
#                 NP_476509  NP_848648  NP_001792  NP_115928  NP_149040  \
# AO-A12D.01TCGA  -0.683045        NaN  -5.940566   5.656460   0.825636
# C8-A131.01TCGA   2.010857        NaN   0.266220  -1.215305   0.136688
# AO-A12B.01TCGA   1.762440        NaN  -3.461788  -2.530573   1.887156
# BH-A18Q.02TCGA   2.078791        NaN   0.750674  -7.070829   2.895064
# C8-A130.02TCGA   2.300389        NaN   0.929404   2.762850   1.755930
#
#                 NP_775928  NP_001185982  NP_001001850  NP_005369  \
# AO-A12D.01TCGA  -1.585967           NaN      0.943739        NaN
# C8-A131.01TCGA   5.394885           NaN      1.108179        NaN
# AO-A12B.01TCGA  -1.688045           NaN     -3.317671        NaN
# BH-A18Q.02TCGA   0.670385    -12.781396     -6.569021        NaN
# C8-A130.02TCGA   2.746451      0.106156      0.175034        NaN
#
#                 NP_001013642  NP_073618  NP_848578  NP_996805  NP_001161940  \
# AO-A12D.01TCGA           NaN   0.909451  -0.042998  -5.079552           NaN
# C8-A131.01TCGA           NaN   1.602021  -4.251215  -5.433196           NaN
# AO-A12B.01TCGA           NaN  -2.877007   0.396103  -6.521495           NaN
# BH-A18Q.02TCGA     -0.296430  -7.565945   3.467124        NaN      3.189457
# C8-A130.02TCGA     -1.038518   1.503381  -1.284508        NaN      0.099597
#
#                 NP_997625  NP_003270  NP_078879  NP_060152  NP_036314  \
# AO-A12D.01TCGA   1.637123  -0.252537  -5.475771  -4.866203        NaN
# C8-A131.01TCGA   1.059605   2.193011   0.124544  -1.555326        NaN
# AO-A12B.01TCGA   1.648810  -2.813263  -7.350166  -3.564333        NaN
# BH-A18Q.02TCGA   0.422827   0.389373   0.513152   2.717759  -7.094246
# C8-A130.02TCGA   0.493181   2.369266  -0.100475  -0.674452   2.467662
#
#                 NP_849155  NP_001012414  NP_612396  NP_001073947  NP_001486  \
# AO-A12D.01TCGA        NaN           NaN        NaN           NaN        NaN
# C8-A131.01TCGA        NaN           NaN        NaN           NaN        NaN
# AO-A12B.01TCGA        NaN           NaN        NaN           NaN        NaN
# BH-A18Q.02TCGA  -8.429054     -0.717949        NaN           NaN  -2.410712
# C8-A130.02TCGA  -8.323107      0.152075        NaN           NaN   3.012120
#
#                 NP_001013757  NP_001158162  NP_057655  NP_937858  NP_005363  \
# AO-A12D.01TCGA           NaN           NaN   1.038984   2.578143        NaN
# C8-A131.01TCGA           NaN           NaN   0.658864   3.957887        NaN
# AO-A12B.01TCGA           NaN           NaN  -0.000217   0.423818        NaN
# BH-A18Q.02TCGA     -7.094246    -11.249211   0.101670  -2.577981        NaN
# C8-A130.02TCGA      2.467662     -6.145274   0.450543   0.339027        NaN
#
#                 XP_003118572  NP_001009606  NP_057125  NP_036318  NP_066009  \
# AO-A12D.01TCGA      4.749728           NaN  -0.534462        NaN   2.185733
# C8-A131.01TCGA     -0.268100           NaN   1.970378        NaN  -1.114107
# AO-A12B.01TCGA      0.695423           NaN  -0.105533        NaN   6.041596
# BH-A18Q.02TCGA           NaN     -2.892447  -0.801583  -7.094246  -6.699491
# C8-A130.02TCGA           NaN     -0.031598  -1.150033   2.467662  -3.468901
#
#                 NP_653179  NP_068741  NP_112590  NP_872416  NP_001007596  \
# AO-A12D.01TCGA  -1.410716  -0.846866   1.374246        NaN           NaN
# C8-A131.01TCGA   0.156927  -0.320723   1.019126        NaN           NaN
# AO-A12B.01TCGA  -0.332794  -1.130979  -2.513944        NaN           NaN
# BH-A18Q.02TCGA  -1.116049  -0.313157        NaN  -0.731330      0.877799
# C8-A130.02TCGA  -0.815487   1.598497        NaN   1.808408      0.853967
#
#                 NP_002460  NP_115956  NP_006685  NP_004464  NP_036224  \
# AO-A12D.01TCGA   1.096131        NaN   2.543854        NaN   0.787538
# C8-A131.01TCGA   0.666960        NaN  -1.142443        NaN   0.662912
# AO-A12B.01TCGA  -1.427526        NaN  -0.318937        NaN  -1.541157
# BH-A18Q.02TCGA        NaN        NaN   0.449590  -7.094246        NaN
# C8-A130.02TCGA        NaN        NaN  -2.937562   2.467662        NaN
#
#                 NP_001092808  NP_694948  NP_000610  NP_699178  NP_955523  \
# AO-A12D.01TCGA      1.259953  -5.239563        NaN  -0.294445   2.501947
# C8-A131.01TCGA      0.561715  -1.919636        NaN   1.205328   0.173119
# AO-A12B.01TCGA     -1.571643  -5.509907        NaN  -2.580459  -1.956878
# BH-A18Q.02TCGA      0.275630  -2.112973  -9.750480   1.292626        NaN
# C8-A130.02TCGA     -0.090636   2.064238   0.745731  -0.933562        NaN
#
#                 NP_006140  NP_001138229  NP_068835  NP_001906  NP_112509  \
# AO-A12D.01TCGA        NaN           NaN   0.547520        NaN   1.507589
# C8-A131.01TCGA        NaN           NaN   0.274316        NaN  -0.045467
# AO-A12B.01TCGA        NaN           NaN   4.023963        NaN  -3.317671
# BH-A18Q.02TCGA  -1.554294     -4.565138  -0.002037        NaN  -3.340728
# C8-A130.02TCGA   2.753011      0.145515   1.165554        NaN   2.270870
#
#                 NP_065933  NP_872308  NP_055176  NP_997279  NP_060529  \
# AO-A12D.01TCGA        NaN  -0.865915        NaN   0.040817        NaN
# C8-A131.01TCGA        NaN  -2.016785        NaN   2.869007        NaN
# AO-A12B.01TCGA        NaN  -2.128709        NaN  -0.873232        NaN
# BH-A18Q.02TCGA        NaN  -9.640082        NaN        NaN  -1.336844
# C8-A130.02TCGA        NaN  -1.284508        NaN        NaN   3.002281
#
#                 NP_001129479  NP_004051  NP_114404  NP_612382  NP_003927  \
# AO-A12D.01TCGA      1.922857  -4.058526        NaN   2.936264   4.646863
# C8-A131.01TCGA      0.545524  -4.522423        NaN  -0.324771  -0.571691
# AO-A12B.01TCGA     -2.053879  -6.230491        NaN  -3.012809  -4.611950
# BH-A18Q.02TCGA     -1.581057  -6.431861        NaN  -4.240636  -9.071367
# C8-A130.02TCGA     -2.927722  -0.349745        NaN  -2.409503  -0.795808
#
#                 NP_061841  NP_001014979  NP_848561  NP_000331  NP_690591  \
# AO-A12D.01TCGA        NaN      0.025578  -0.100145        NaN        NaN
# C8-A131.01TCGA        NaN      1.691074   0.007156        NaN        NaN
# AO-A12B.01TCGA        NaN     -2.863150  -0.593313        NaN        NaN
# BH-A18Q.02TCGA -20.331922     -3.210258  -2.598053  -3.936206        NaN
# C8-A130.02TCGA   3.425384     -0.041438   0.598137  -0.494060        NaN
#
#                 XP_003960234  NP_000237  NP_057387  NP_004187  NP_065087  \
# AO-A12D.01TCGA     -2.881298        NaN  -2.058382        NaN        NaN
# C8-A131.01TCGA      1.079844        NaN  -5.890607        NaN        NaN
# AO-A12B.01TCGA     -1.308353        NaN  -6.413408        NaN        NaN
# BH-A18Q.02TCGA           NaN -10.680496 -12.028685   3.360072        NaN
# C8-A130.02TCGA           NaN   0.460382  -3.678812   1.962562        NaN
#
#                 NP_004953  NP_001034806  NP_065119  NP_110392  NP_620138  \
# AO-A12D.01TCGA        NaN      1.275192   0.787538        NaN        NaN
# C8-A131.01TCGA        NaN      1.314621   0.662912        NaN        NaN
# AO-A12B.01TCGA        NaN      0.529134  -1.541157        NaN        NaN
# BH-A18Q.02TCGA  -2.159808     -3.414326        NaN        NaN        NaN
# C8-A130.02TCGA   1.742811     -1.619055        NaN        NaN        NaN
#
#                 NP_062558  NP_001005163  NP_665813  NP_005279  NP_998761  \
# AO-A12D.01TCGA   0.825636      1.454252   0.840875        NaN   0.139872
# C8-A131.01TCGA   0.136688      1.002934   1.468441        NaN  -0.446207
# AO-A12B.01TCGA   1.887156     -4.900183  -0.837202        NaN  -2.228482
# BH-A18Q.02TCGA   2.895064           NaN        NaN -13.547488  -4.896331
# C8-A130.02TCGA   1.755930           NaN        NaN  -0.061117   0.693253
#
#                 YP_003024032  NP_001165887  NP_001010893  NP_872303  \
# AO-A12D.01TCGA           NaN      0.932310           NaN        NaN
# C8-A131.01TCGA           NaN      1.229616           NaN        NaN
# AO-A12B.01TCGA           NaN      0.756395           NaN        NaN
# BH-A18Q.02TCGA     -4.708989           NaN           NaN  -2.865684
# C8-A130.02TCGA     -1.648573           NaN           NaN  -3.586976
#
#                 NP_000871  NP_690872  NP_683762  NP_060064  NP_699174  \
# AO-A12D.01TCGA        NaN        NaN        NaN        NaN        NaN
# C8-A131.01TCGA        NaN        NaN        NaN        NaN        NaN
# AO-A12B.01TCGA        NaN        NaN        NaN        NaN        NaN
# BH-A18Q.02TCGA   0.723911        NaN        NaN        NaN   0.583405
# C8-A130.02TCGA   3.120356        NaN        NaN        NaN   0.332467
#
#                 NP_001164045  NP_001193600  NP_061134  NP_932347  NP_003593  \
# AO-A12D.01TCGA     -1.231655           NaN        NaN        NaN  -0.340163
# C8-A131.01TCGA     -4.279550           NaN        NaN        NaN   3.451902
# AO-A12B.01TCGA     -4.462290           NaN        NaN        NaN  -1.718531
# BH-A18Q.02TCGA    -11.864761      0.048144        NaN  -0.881872   2.527072
# C8-A130.02TCGA      0.115996      1.457462        NaN   1.710012   0.296389
#
#                 NP_997203  NP_001191293  NP_775791  NP_004065  NP_068752  \
# AO-A12D.01TCGA        NaN           NaN        NaN        NaN  -0.633517
# C8-A131.01TCGA        NaN           NaN        NaN        NaN   4.840325
# AO-A12B.01TCGA        NaN           NaN        NaN        NaN  -1.965192
# BH-A18Q.02TCGA  -8.111243    -16.029761  -2.046065  -1.778435        NaN
# C8-A130.02TCGA  -1.753529      1.729692  -0.425182  -0.149673        NaN
#
#                 NP_219494
# AO-A12D.01TCGA  12.666488
# C8-A131.01TCGA   0.140736
# AO-A12B.01TCGA  -2.854835
# BH-A18Q.02TCGA  -3.069752
# C8-A130.02TCGA  -0.047997

# %% [markdown]
# ##### get NA values

# %%
na_val=reshaped_proteome.isna().sum()
na_val[na_val>0].shape,na_val[na_val>2].shape
# Out:
# ((4559,), (4314,))

# %% [markdown]
# #### 4559 features (proteins) have unfilled data in samples causing NA values, of them 4314 features have NA values greater than 2.5 % of the sample size

# %%
na_val.sort_values(ascending=False).plot(kind='hist',bins=20)
plt.ylabel('frequency',fontsize=22,weight='bold')
plt.xlabel('NA values',fontsize=22,weight='bold')
plt.show()

# %% [markdown]
# ## Observation
# ### we can clearly see that there are several features (proteins) with missing values in more than 10 samples,  which corresponds to > 10 % of 83 samples. such features with excessive missing values will cause errors and have to be removed

# %%
# get list of features with NA values greater than 2
na_val_index=na_val[na_val>8].index.tolist()

# %%
# filter columns in dataset to remove feaures with NA values greater than 2 
comp_cases=[n for n in reshaped_proteome.columns if n not in na_val_index]

# %%
# number of features (proteins) with less than 2 NA values
len(comp_cases)
# Out:
# 9334

# %%
fl_proteome=reshaped_proteome[comp_cases]
fl_proteome.shape
# Out:
# (83, 9334)

# %%
fl_proteome=fl_proteome.fillna(fl_proteome.mean()) # NA values filled with mean

# %%
fl_proteome.isna().sum().sort_values(ascending=False)
# Out:
# NP_068835       0
# NP_036244       0
# NP_000512       0
# NP_003070       0
# NP_619579       0
#                ..
# NP_000104       0
# NP_001243439    0
# NP_079202       0
# NP_002872       0
# NP_958782       0
# Length: 9334, dtype: int64

# %% [markdown]
# ## **no NA values, all features are filled with values**

# %% [markdown]
# # Scaling the data and removing outliers

# %%
from sklearn.preprocessing import StandardScaler

# %%
# scaling the data
scaler=StandardScaler()
scaled_proteome=scaler.fit_transform(fl_proteome)
scaled_proteome=pd.DataFrame(scaled_proteome)
scaled_proteome.columns=fl_proteome.columns

# %%
# visualizing data before and after scaling
x=[np.random.randint(0,9000) for n in range(50)]
data1=fl_proteome.iloc[:,x]
data2=scaled_proteome.iloc[:,x]
fig,axs=plt.subplots(2,sharex=True,figsize=(25,8))
ag=sns.boxplot(data=data1,ax=axs[0])
ag.legend(['before scaling'],loc='lower right')
bg=sns.boxplot(data=data2,ax=axs[1])
bg.legend(['after scaling'],loc='lower right')
bg.set_xticklabels(x)
plt.xticks(rotation=90)
ag.set_title('features chosen randomly')
plt.show()

# %%
# removal of outliers
from scipy import stats
z = np.abs(stats.zscore(scaled_proteome))

threshold=3
z_bool=np.all(z<threshold,axis=0)

# %%
zscaled_proteome=scaled_proteome.loc[:,z_bool]

zscaled_proteome.shape # dataset after scaling and removing outliers
# Out:
# (83, 5198)

# %%
zscaled_proteome_lst=zscaled_proteome.columns.tolist()

# %% [markdown]
# The last 3 samples are healthy tissue.We have created a column 'Type', and labelled cancer tissue
# as Cancer and healthy tissue as Healthy

# %%
fl_proteome['Type']="Cancer"
fl_proteome.iloc[-3:,-1]="Healthy"

# %% [markdown]
# ### Cancer samples type

# %%
fl_proteome.iloc[:3,-1]
# Out:
# AO-A12D.01TCGA    Cancer
# C8-A131.01TCGA    Cancer
# AO-A12B.01TCGA    Cancer
# Name: Type, dtype: object

# %% [markdown]
# ### Healthy samples type

# %%
fl_proteome.iloc[-3:,-1]
# Out:
# 263d3f-I.CPTAC    Healthy
# blcdb9-I.CPTAC    Healthy
# c4155b-C.CPTAC    Healthy
# Name: Type, dtype: object

# %% [markdown]
# ### Distribution of samples in the dataset

# %%
fl_proteome.Type.value_counts().plot(kind='bar',figsize=(4,3),rot=0)
plt.show()

# %% [markdown]
# ### There is an imbalance in the 2 classes in this dataset

# %% [markdown]
# ### There is an imbalance in the 2 classes in this dataset

# %% [markdown]
# ### The distribution of fold change in proteins in the cancer samples

# %%
# we are choosing only cancer samples
cancer_proteome=fl_proteome.iloc[:-3,:-1]
cancer_proteome.shape
# Out:
# (80, 9334)

# %%
cancer_mean_list=cancer_proteome.mean().values.tolist()

# %%
cmean=cancer_proteome.mean()
cstd=cancer_proteome.std()

# %%
cmean.name='mean_cancer'
cstd.name='std_cancer'

# %%
# mean and median of the cancer samples
print(f'mean cancer dataset {cmean.mean()}, medain cancer dataset {cmean.median()}')
# Out:
# mean cancer dataset -0.15374947663780825, medain cancer dataset -0.04141685377500001

# %%
fig=plt.figure(figsize=(8,3))
sns.distplot(cancer_mean_list,hist=True,axlabel="Fold Change")
plt.legend(['cancer'])
plt.xlabel('Fold Change',fontsize=22,weight='bold')
plt.ylabel('Density',fontsize=22,weight='bold')
plt.show()

# %% [markdown]
# ### Observation
# ### The distribution appears normal with negative skew with mean less than median

# %% [markdown]
# ### The distribution of fold change in proteins in the healthy samples

# %%
# we are choosing healthy samples in the dataset
Healthy_proteome=fl_proteome.iloc[-3:,:-1]
Healthy_proteome.shape
# Out:
# (3, 9334)

# %%
healthy_mean_list=Healthy_proteome.mean().values.tolist()

# %%
hmean=Healthy_proteome.mean()
hstd=Healthy_proteome.std()

# %%
hmean.name='mean_healthy'
hstd.name='std_healthy'

# %%
# mean and median of the healthy samples
print(f'mean healthy dataset {hmean.mean()}, median healthy dataset {hmean.median()}')
# Out:
# mean healthy dataset 0.10014919606134338, median healthy dataset 0.03046302883333334

# %%
fig=plt.figure(figsize=(8,3))
sns.distplot(healthy_mean_list,hist=True,axlabel="Fold Change")
plt.legend(['healthy'])
plt.xlabel('Fold Change',fontsize=22,weight='bold')
plt.ylabel('Density',fontsize=22,weight='bold')
plt.show()

# %% [markdown]
# ### Observation
# ### The distribution appears as Normal distribution with mean greater than median

# %% [markdown]
# ### superimposing both the cancer and healthy sample expression levels

# %%
fig=plt.figure(figsize=(10,4))
g=sns.distplot(cancer_mean_list,hist=True,axlabel="Fold Change")
h=sns.distplot(healthy_mean_list,hist=True,axlabel="Fold Change")
plt.legend(['cancer','healthy'])
plt.xlabel('Fold Change',fontsize=22,weight='bold')
plt.ylabel('Density',fontsize=22,weight='bold')
plt.show()

# %% [markdown]
# ### Observation
# ### There is a shift in the abundance of proteins in cancer samples and a remarkable uniformity in their abundance, as compared to normal samples. It would be worthwhile to see proteins overexpressed in cancer as compared to healthy samples. iTRAQ measures protein abundance. The levels of protein can fall by proteolytic  processing and/or lower expression. The levels will rise due to increased expression

# %%
proteome_foldchange_df=pd.concat([gene_name_df,cmean,cstd,hmean,hstd],axis=1,join='inner')

# %%
proteome_foldchange_df['log_coeffvar_cncr']=np.log10(np.abs(proteome_foldchange_df.std_cancer/proteome_foldchange_df.mean_cancer))
proteome_foldchange_df['log_coeffvar_hlth']=np.log10(np.abs(proteome_foldchange_df.std_healthy/proteome_foldchange_df.mean_healthy))

# %%
proteome_foldchange_df
# Out:
#           gene_symbol                                          gene_name  \
# NP_958782        PLEC                                  plectin isoform 1
# NP_958785         NaN                                 plectin isoform 1g
# NP_958786        PLEC                                 plectin isoform 1a
# NP_000436         NaN                                 plectin isoform 1c
# NP_958781         NaN                                 plectin isoform 1e
# ...               ...                                                ...
# NP_078879       BEND5                    BEN domain-containing protein 5
# NP_653179   MAPK1IP1L  MAPK-interacting and spindle-stabilizing prote...
# NP_699178     TMEM86A            lysoplasmalogenase-like protein TMEM86A
# NP_006140      LGALS4                                         galectin-4
# NP_068835        UTS2                urotensin-2 isoform a preproprotein
#
#            mean_cancer  std_cancer  mean_healthy  std_healthy  \
# NP_958782     0.320062    0.992604      0.324758     0.447186
# NP_958785     0.326656    0.995952      0.333827     0.448599
# NP_958786     0.326232    0.995815      0.331573     0.448458
# NP_000436     0.323387    0.994313      0.331573     0.448458
# NP_958781     0.326678    0.996615      0.337887     0.437526
# ...                ...         ...           ...          ...
# NP_078879     0.885437    3.638328      5.507378     3.157078
# NP_653179    -0.119336    0.980365     -0.119336     0.000000
# NP_699178     0.128945    1.703473     -0.407810     0.440161
# NP_006140     0.629517    2.446497      1.492421     2.637144
# NP_068835     0.171520    1.391458     -1.876604     0.869564
#
#            log_coeffvar_cncr  log_coeffvar_hlth
# NP_958782           0.491541           0.138927
# NP_958785           0.484148           0.128336
# NP_958786           0.484652           0.131143
# NP_000436           0.487800           0.131143
# NP_958781           0.484407           0.112232
# ...                      ...                ...
# NP_078879           0.613744          -0.241660
# NP_653179           0.914618               -inf
# NP_699178           1.120932           0.033154
# NP_006140           0.589537           0.247243
# NP_068835           0.909156          -0.334071
#
# [9334 rows x 8 columns]

# %% [markdown]
# ### The changes in cancer would be due to overexpression of genes or repression of genes, and this will be reflected in the levels of the protein. Since absolute levels are not given, we  cannot compare the levels of protein in cancer and healthy samples directly. To compare cancer and healthy samples,we shall use the concept of Housekeeping genes. The expression of these genes is fairly constant and the proteins are present at constant levels. Prominently GAPDH, beta actin, beta tubulin are also used as loadng controls in western blots. A paper also cites that ribosome protein levels are fairly constant (Geiger T, Wehner A, Schaab C, Cox J, Mann M.  Mol Cell Proteomics. 2012 Mar;11(3))

# %% [markdown]
# ## Housekeeping Genes

# %%
housekeeping=['NP_000968','NP_000966','NP_001013','NP_001017963','NP_057004','NP_821133','NP_001092','NP_002037','NP_000960']

# %% [markdown]
# ### List of housekeeping proteins

# %%
proteome_foldchange_df.loc[housekeeping,:]
# Out:
#              gene_symbol                                          gene_name  \
# NP_000968            NaN                60S ribosomal protein L13 isoform 1
# NP_000966          RPL11                60S ribosomal protein L11 isoform 1
# NP_001013            NaN                          40S ribosomal protein S19
# NP_001017963         NaN          heat shock protein HSP 90-alpha isoform 1
# NP_057004         RPS27L                     40S ribosomal protein S27-like
# NP_821133           TUBB                                 tubulin beta chain
# NP_001092           ACTB                               actin, cytoplasmic 1
# NP_002037        GAPDHL6  glyceraldehyde-3-phosphate dehydrogenase isofo...
# NP_000960            NaN                           60S ribosomal protein L5
#
#               mean_cancer  std_cancer  mean_healthy  std_healthy  \
# NP_000968       -0.245194    1.517420     -0.569403     1.148383
# NP_000966        0.158824    0.469693     -0.120288     0.383864
# NP_001013        0.155284    1.037320     -0.100351     0.329323
# NP_001017963     0.054743    0.702963     -0.793373     0.091350
# NP_057004        0.181793    0.841232     -0.136627     0.427549
# NP_821133        0.257342    0.512544     -0.463977     0.347398
# NP_001092        0.323812    0.741426      0.688672     0.308608
# NP_002037       -0.129247    0.848575      0.874110     0.291477
# NP_000960        0.031497    0.870826     -0.774514     0.177887
#
#               log_coeffvar_cncr  log_coeffvar_hlth
# NP_000968              0.791595           0.304667
# NP_000966              0.470897           0.503955
# NP_001013              0.824785           0.516100
# NP_001017963           1.108606          -0.938771
# NP_057004              0.665338           0.495448
# NP_821133              0.299221          -0.125669
# NP_001092              0.359774          -0.348605
# NP_002037              0.817269          -0.476961
# NP_000960              1.441665          -0.638885

# %%
house_names=['RPL13','RPL11','RPS19','HSP90','RPS27','TUBB','ACTB','GAPDH','RPL5']

# %%
housekeeping_cancer=cancer_proteome[housekeeping]

# %%
housekeeping_healthy=Healthy_proteome[housekeeping]

# %%
fig,axs=plt.subplots(2,sharex=True,figsize=(16,8))
ghk=sns.boxplot(data=housekeeping_cancer,ax=axs[0])
ghk.set_title('Fold Change of Housekeeping Genes')
ghk.legend(["cancer"],loc='lower right')
hhk=sns.boxplot(data=housekeeping_healthy,ax=axs[1])
hhk.legend(["healthy"],loc='lower right')
hhk.set_xticklabels(house_names,rotation=90)
hhk.set(ylim=(-3,3))
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# ## Observation
# ### Ribosomal protein L11 (RPL11) and beta tubulin (TUBB) can be suitably used to study cancer related protein changes. We shall use beta tubulin, as we can co-relate our study with previous experimental studies

# %% [markdown]
# ### proteins with fold change greater than beta-tubulin

# %%
proteome_foldchange_df['corrected_cancer']=proteome_foldchange_df.mean_cancer-0.257342
proteome_foldchange_df['corrected_health']=proteome_foldchange_df.mean_healthy-(-0.463977)

# %%
proteome_foldchange_df['foldchange_cancer']=proteome_foldchange_df['corrected_cancer']-proteome_foldchange_df['corrected_health']

# %%
proteome_foldchange_df['composite_coeff']=proteome_foldchange_df['log_coeffvar_cncr']+proteome_foldchange_df['log_coeffvar_hlth']

# %%
cancer_altered_df=proteome_foldchange_df.loc[:,['gene_name','corrected_cancer','corrected_health','foldchange_cancer','composite_coeff']]

# %%
fig=plt.figure()
fig=sns.scatterplot(data=cancer_altered_df, x='foldchange_cancer',y='composite_coeff')
fig.set_ylim(-2,5)
fig.set_xlabel('Fold change cancer',fontsize=22,weight='bold')
fig.set_ylabel('composite variation',fontsize=22,weight='bold')
plt.show()

# %%
# test for normality of 'foldchange' in cancer_altered_df
from scipy import stats
stats.kstest(cancer_altered_df.foldchange_cancer,'norm',alternative='greater')
# Out:
# KstestResult(statistic=0.34086639471704827, pvalue=0.0)

# %% [markdown]
# ### foldchange values are normally distributed

# %%
# calculate z-score  for foldchange 
cancer_altered_df['zscore_foldchange']=np.abs(stats.zscore(cancer_altered_df.foldchange_cancer))

# %%
# calculate p-value for foldchange
from scipy.special import ndtr as ndtr
cancer_altered_df['pvalue_foldchange']=1- ndtr(cancer_altered_df.zscore_foldchange)

# %%
cancer_altered_df.head()
# Out:
#                     gene_name  corrected_cancer  corrected_health  \
# NP_958782   plectin isoform 1          0.062720          0.788735
# NP_958785  plectin isoform 1g          0.069314          0.797804
# NP_958786  plectin isoform 1a          0.068890          0.795550
# NP_000436  plectin isoform 1c          0.066045          0.795550
# NP_958781  plectin isoform 1e          0.069336          0.801864
#
#            foldchange_cancer  composite_coeff  zscore_foldchange  \
# NP_958782          -0.726015         0.630469           0.195377
# NP_958785          -0.728490         0.612484           0.193436
# NP_958786          -0.726659         0.615794           0.194872
# NP_000436          -0.729504         0.618942           0.192641
# NP_958781          -0.732528         0.596639           0.190271
#
#            pvalue_foldchange
# NP_958782           0.422549
# NP_958785           0.423309
# NP_958786           0.422747
# NP_000436           0.423620
# NP_958781           0.424549

# %%
# proteins with statistically significant foldchange 
significant_fold_change=cancer_altered_df[cancer_altered_df.pvalue_foldchange<0.025]

# %%
significant_fold_change.shape
# Out:
# (525, 7)

# %%
# upregulated proteins in cancer
significant_fold_change[significant_fold_change.corrected_cancer>significant_fold_change.corrected_health].sort_values(by='foldchange_cancer',ascending=False).head(n=20)
# Out:
#                                                       gene_name  \
# NP_663722     amyloid beta A4 precursor protein-binding fami...
# NP_006724                                  centromere protein I
# XP_001126659                  PREDICTED: prothymosin alpha-like
# NP_060945                   transmembrane protein 165 precursor
# NP_057204                      E3 ubiquitin-protein ligase RLIM
# NP_116175         zinc finger CCCH domain-containing protein 10
# NP_001036148        E3 ubiquitin-protein ligase SHPRH isoform a
# NP_003077            snRNA-activating protein complex subunit 4
# NP_848697        minor histocompatibility antigen H13 isoform 4
# NP_932348              coiled-coil domain-containing protein 57
# XP_003119575                  PREDICTED: prothymosin alpha-like
# NP_115560                   rho GTPase-activating protein SYDE2
# NP_001076804                  zinc finger protein 112 isoform 1
# NP_004263                     homer protein homolog 1 isoform 1
# NP_620134                  testis-expressed sequence 30 protein
# NP_612143                               zinc finger protein 681
# NP_203753                          centrosomal protein KIAA1731
# NP_071374     activating signal cointegrator 1 complex subun...
# NP_612409           nucleolar MIF4G domain-containing protein 1
# NP_001230618        LETM1 domain-containing protein 1 isoform 3
#
#               corrected_cancer  corrected_health  foldchange_cancer  \
# NP_663722            -1.137250         -7.450612           6.313362
# NP_006724            -3.047616         -7.751081           4.703464
# XP_001126659         -1.719344         -6.102094           4.382750
# NP_060945            -1.383849         -5.377617           3.993768
# NP_057204            -1.513560         -5.275367           3.761807
# NP_116175            -3.361746         -6.900061           3.538315
# NP_001036148         -1.747337         -5.135289           3.387952
# NP_003077            -1.556381         -4.862763           3.306381
# NP_848697            -1.076868         -4.364721           3.287852
# NP_932348            -1.134084         -4.401144           3.267060
# XP_003119575         -2.493761         -5.716274           3.222513
# NP_115560            -0.483710         -3.609917           3.126208
# NP_001076804         -1.064145         -4.061967           2.997822
# NP_004263            -0.442595         -3.384361           2.941765
# NP_620134            -0.248205         -3.183080           2.934875
# NP_612143            -1.171236         -4.061967           2.890731
# NP_203753            -1.389603         -4.266462           2.876859
# NP_071374            -0.216003         -3.086270           2.870267
# NP_612409            -1.241035         -3.982665           2.741630
# NP_001230618         -0.926174         -3.657872           2.731698
#
#               composite_coeff  zscore_foldchange  pvalue_foldchange
# NP_663722            0.091705           5.714305       5.507655e-09
# NP_006724           -0.139397           4.452132       4.251086e-06
# XP_001126659        -0.024877           4.200690       1.330513e-05
# NP_060945           -0.037455           3.895725       4.895278e-05
# NP_057204            0.059114           3.713866       1.020585e-04
# NP_116175           -0.197301           3.538646       2.010921e-04
# NP_001036148         0.016645           3.420760       3.122320e-04
# NP_003077            0.062023           3.356808       3.942391e-04
# NP_848697           -0.005285           3.342281       4.154641e-04
# NP_932348            0.303025           3.325980       4.405416e-04
# XP_003119575        -0.082424           3.291055       4.990619e-04
# NP_115560            0.391000           3.215550       6.509730e-04
# NP_001076804        -0.279800           3.114895       9.200520e-04
# NP_004263           -0.041264           3.070946       1.066908e-03
# NP_620134            1.639942           3.065544       1.086372e-03
# NP_612143           -0.384798           3.030935       1.218988e-03
# NP_203753           -0.198100           3.020059       1.263626e-03
# NP_071374            0.907924           3.014891       1.285358e-03
# NP_612409           -0.208116           2.914039       1.783929e-03
# NP_001230618        -0.240245           2.906252       1.828935e-03

# %%
# downregulated proteins in cancer
significant_fold_change[significant_fold_change.corrected_cancer<significant_fold_change.corrected_health].sort_values(by='foldchange_cancer').head(n=20)
# Out:
#                                                     gene_name  \
# NP_002643               prolactin-inducible protein precursor
# NP_477521                      mucin-like protein 1 precursor
# NP_000175                          hemoglobin subunit gamma-2
# NP_000550                          hemoglobin subunit gamma-1
# NP_005321                          hemoglobin subunit epsilon
# NP_002635         polymeric immunoglobulin receptor precursor
# NP_002280                         alpha-lactalbumin precursor
# NP_001015038             putative G antigen family E member 3
# NP_997222                           P antigen family member 2
# NP_940887          tumor protein p63-regulated gene 1 protein
# NP_000549                            hemoglobin subunit alpha
# NP_001729                                carbonic anhydrase 1
# NP_000509                             hemoglobin subunit beta
# NP_003406                   zinc finger protein 268 isoform a
# NP_665683                        glutathione S-transferase A1
# NP_000837                        glutathione S-transferase A2
# NP_001244109         sodium-dependent phosphate transporter 2
# NP_000510                            hemoglobin subunit delta
# NP_002611                 platelet factor 4 variant precursor
# NP_000110     erythrocyte membrane protein band 4.2 isoform 1
#
#               corrected_cancer  corrected_health  foldchange_cancer  \
# NP_002643            -5.246433          5.821319         -11.067752
# NP_477521            -5.713769          4.856033         -10.569802
# NP_000175            -2.823395          6.843509          -9.666904
# NP_000550            -2.738656          6.798931          -9.537587
# NP_005321            -1.239591          7.784921          -9.024512
# NP_002635            -3.268330          5.649090          -8.917420
# NP_002280            -7.809379          0.408375          -8.217755
# NP_001015038         -9.454601         -1.460870          -7.993730
# NP_997222            -9.391177         -1.460870          -7.930307
# NP_940887            -3.788971          3.861980          -7.650952
# NP_000549            -1.884850          5.605159          -7.490009
# NP_001729            -1.967708          5.436111          -7.403819
# NP_000509            -1.730498          5.627670          -7.358168
# NP_003406            -1.089456          6.256468          -7.345924
# NP_665683            -3.818808          3.522240          -7.341048
# NP_000837            -3.926391          3.402773          -7.329164
# NP_001244109         -0.815642          6.442984          -7.258625
# NP_000510            -1.809501          5.416344          -7.225844
# NP_002611             0.028521          7.048183          -7.019662
# NP_000110            -1.654615          5.302729          -6.957344
#
#               composite_coeff  zscore_foldchange  pvalue_foldchange
# NP_002643           -0.240915           7.912628       1.221245e-15
# NP_477521           -0.041097           7.522231       2.697842e-14
# NP_000175           -0.405252           6.814352       4.734435e-12
# NP_000550           -0.378826           6.712967       9.535372e-12
# NP_005321           -0.015608           6.310712       1.388772e-10
# NP_002635           -0.044820           6.226751       2.381038e-10
# NP_002280            1.432013           5.678207       6.805678e-09
# NP_001015038        -0.387423           5.502571       1.871466e-08
# NP_997222           -0.383068           5.452846       2.478501e-08
# NP_940887           -0.204256           5.233829       8.301692e-08
# NP_000549           -0.235855           5.107649       1.630962e-07
# NP_001729           -0.155332           5.040075       2.326745e-07
# NP_000509           -0.197117           5.004285       2.803492e-07
# NP_003406            0.027047           4.994686       2.946584e-07
# NP_665683           -0.034236           4.990862       3.005515e-07
# NP_000837           -0.042333           4.981545       3.153931e-07
# NP_001244109         0.507239           4.926242       4.191299e-07
# NP_000510           -0.162810           4.900542       4.778638e-07
# NP_002611            0.249437           4.738893       1.074443e-06
# NP_000110           -0.082737           4.690035       1.365789e-06

# %%
# fig=plt.figure()
# fig=sns.scatterplot(data=scaled_proteome, x='foldchange_cancer',y='composite_coeff')
# fig.set_ylim(-2,5)
# fig.set_xlabel('Fold change cancer',fontsize=22,weight='bold')
# fig.set_ylabel('composite variation',fontsize=22,weight='bold')
# plt.show()
